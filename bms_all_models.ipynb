# %%
# %matplotlib notebook

# %%
MODEL = 'boost' # ['python', 'cython', 'boost']

# %%
# %run -i sim.py

# %%
# %run -i bms.py
# Out:
# <img src="data:image/png;base64,...">
# Building probability distribution model...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/rog/Workspace/bms/msd/bms.py in <module>()
#     142         # Define objective function: returns the array to be minimized
#     143
# --> 144     class Meanfcn(object):
#     145         def __init__(self, z0, T, G, kws, FF):
#     146             self.z0 = z0
#
# /home/rog/Workspace/bms/msd/bms.py in Meanfcn()
#     154         @mc.deterministic
#     155         # def mean(Z=Z, Zdot=Zdot, k=pd_k, b=pd_b, d=pd_d):
# --> 156         def mean(self, k=P['k'], b=P['b'], d=P['d']):
#     157         # def mean(**P):
#     158             # Fe = k*Z[:,0] + b*Zdot[:,0] + d*E[:,0]
#
# /home/rog/.virtualenvs/bms/local/lib/python2.7/site-packages/pymc/InstantiationDecorators.pyc in deterministic(__func__, **kwds)
#     248
# ...

# %%
# %matplotlib notebook

# %%
MODEL = 'cython' # ['python', 'cython', 'boost']

# %%
PLOT_SIM = True

# %%
# %run -i sim.py
# Out:
# <img src="data:image/png;base64,...">

# %%
OPTFUN = 'lmfit' # ['optimize', 'lmfit']

# %%
PLOT_ESTIM = True

# %%
# %run -i estim.py
# Out:
# <img src="data:image/png;base64,...">
# Time elapsed: 7.899081 seconds
#
#             TRUE      F_EST
# k    :   -50.0000   -48.5297
# b    :   -10.0000    -9.6603
# d    :     1.0000     1.0141

# %%
# %reset -f

# %%
MODEL = 'cython' # ['python', 'cython', 'boost']

# %%
# %run -i sim.py

# %%
OPTFUN = 'lmfit' # ['optimize', 'lmfit']

# %%
PLOT_ESTIM = True

# %%
# %run -i estim.py

# %%
# %reset -f

# %%
MODEL = 'boost' # ['python', 'cython', 'boost']

# %%
# %run -i sim.py

# %%
OPTFUN = 'lmfit' # ['optimize', 'lmfit']

# %%
PLOT_ESTIM = True

# %%
# %run -i estim.py

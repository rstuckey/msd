# %%
# %matplotlib notebook

# %%
MODEL = 'python' # ['python', 'cython', 'boost']

# %%
PLOT_SIM = True

# %%
# %run -i sim.py
# Out:
# <img src="data:image/png;base64,...">

# %%
OPTFUN = 'lmfit' # ['optimize', 'lmfit']

# %%
PLOT_ESTIM = True

# %%
# %run -i estim.py
# Out:
# <img src="data:image/png;base64,...">
# STATISTICAL OPTIMIZATION:
# Optimization terminated successfully.
#          Current function value: 141.334272
#          Iterations: 4
#          Function evaluations: 296
# Time elapsed: 118.553002 seconds
#
#             TRUE      F_EST
#     k:   -50.0000   -49.3606
#     b:   -10.0000    -9.7353
#     d:     1.0000     1.0081

# %%
# %reset -f

# %%
MODEL = 'cython' # ['python', 'cython', 'boost']

# %%
# %run -i sim.py

# %%
OPTFUN = 'lmfit' # ['optimize', 'lmfit']

# %%
PLOT_ESTIM = True

# %%
# %run -i estim.py
# Out:
# <img src="data:image/png;base64,...">
# Time elapsed: 6.948480 seconds
#
#             TRUE      F_EST
# k    :   -50.0000   -48.5297
# b    :   -10.0000    -9.6603
# d    :     1.0000     1.0141

# %%
# %reset -f

# %%
MODEL = 'boost' # ['python', 'cython', 'boost']

# %%
# %run -i sim.py

# %%
OPTFUN = 'lmfit' # ['optimize', 'lmfit']

# %%
PLOT_ESTIM = True

# %%
# %run -i estim.py
# Out:
# <img src="data:image/png;base64,...">
# Time elapsed: 4.433636 seconds
#
#             TRUE      F_EST
# k    :   -50.0000   -48.1269
# b    :   -10.0000   -10.2672
# d    :     1.0000     1.0232

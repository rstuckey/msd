# %%
# %reset -f

# %%
# %matplotlib notebook

# %%
NOISE_SD = 0.01

# %%
STATE_NOISE_SD = 0.0

# %%
MODEL = 'python' # ['python', 'cython', 'boost']

# %%
# %run -i sim.py

# %%
PLOT_REG = True

# %%
# %run -i reg.py
# Out:
# <img src="data:image/png;base64,...">
# LINEAR REGRESSION:
#             TRUE       EST    95% CONF
#     k:   -50.0000   -22.6344 +/-1.7245
#     b:   -10.0000    -4.4541 +/-1.5727
#     d:     1.0000     0.9704 +/-0.0415
# R^2 = 0.6337

# %%
# %matplotlib notebook

# %%
MODEL = 'cython' # ['python', 'cython', 'boost']

# %%
DO_PYMC_MAP = False

# %%
DO_PYMC_MCMC = True

# %%
PLOT_MAP = False

# %%
PLOT_MCMC = False

# %%
NUM_SAMPLES = [ 100, 500 ]

# %%
# %run -i sim.py

# %%
# %run -i bms.py
# Out:
#  BUILDING PROBABILITY DISTRIBUTION MODEL
# <img src="data:image/png;base64,...">
#  BAYES ESTIMATE (MAXIMUM A-PRIORI):
# /home/rog/.virtualenvs/bms/local/lib/python2.7/site-packages/scipy/optimize/optimize.py:1792: RuntimeWarning: invalid value encountered in absolute
#   tmp2 = numpy.abs(tmp2)
# Time elapsed: 00h 00m 57s
#
#             TRUE      M_EST
#     k:   -50.0000   -48.7360
#     b:   -10.0000   -10.3709
#     d:     1.0000     0.9917
#  BAYES ESTIMATE (MARKOV CHAIN MONTE CARLO):
#
#  Chain 0:
#  [-----------------100%-----------------] 1000 of 1000 complete in 177.0 sec
#  Chain 1:
#  [-----------------100%-----------------] 1000 of 1000 complete in 174.0 sec
# Time elapsed: 00h 05m 50s
#             TRUE      B_EST
#     k:   -50.0000   -48.7453
#     b:   -10.0000   -10.2413
#     d:     1.0000     0.9819
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...

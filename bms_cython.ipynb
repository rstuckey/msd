# %%
# %matplotlib notebook

# %%
MODEL = 'cython' # ['python', 'cython', 'boost']

# %%
DO_PYMC_MAP = True

# %%
DO_PYMC_MCMC = True

# %%
PLOT_MAP = True

# %%
PLOT_MCMC = True

# %%
NUM_SAMPLES = [ 100, 500 ]

# %%
# %run -i sim.py

# %%
# %run -i bms.py
# Out:
#  BUILDING PROBABILITY DISTRIBUTION MODEL
# <img src="data:image/png;base64,...">
#  BAYES ESTIMATE (MAXIMUM A-PRIORI):
# /home/rog/.virtualenvs/bms/local/lib/python2.7/site-packages/scipy/optimize/optimize.py:1881: RuntimeWarning: invalid value encountered in absolute
#   tmp2 = numpy.abs(tmp2)
# Time elapsed: 00h 00m 40s
#
#             TRUE      M_EST
#     k:   -50.0000   -48.8208
#     b:   -10.0000   -10.0549
#     d:     1.0000     0.9825
#  BAYES ESTIMATE (MARKOV CHAIN MONTE CARLO):
#  Switch PLOT_MCMC to False for this...
#
#  Chain 0:
#  [-----------------100%-----------------] 100 of 100 complete in 15.4 sec
#  Chain 1:
#  [-----------------100%-----------------] 500 of 500 complete in 77.3 sec
# Time elapsed: 00h 01m 32s
#             TRUE      B_EST
#     k:   -50.0000   -48.1119
#     b:   -10.0000   -10.3134
#     d:     1.0000     0.9906

# %%
PLOT_MAP = False

# %%
PLOT_MCMC = False

# %%
NUM_SAMPLES = [ 100, 5000 ]

# %%
# %run -i bms.py
# Out:
#  BUILDING PROBABILITY DISTRIBUTION MODEL
#
#  BAYES ESTIMATE (MAXIMUM A-PRIORI):
#
# Time elapsed: 00h 00m 03s
#
#             TRUE      M_EST
#     k:   -50.0000   -48.5876
#     b:   -10.0000   -10.2609
#     d:     1.0000     0.9904
#  BAYES ESTIMATE (MARKOV CHAIN MONTE CARLO):
#
#  Chain 0:
#  [-----------------100%-----------------] 100 of 100 complete in 1.8 sec
#  Chain 1:
#  [-----------------100%-----------------] 5001 of 5000 complete in 77.2 sec
# Time elapsed: 00h 01m 18s
#             TRUE      B_EST
#     k:   -50.0000   -48.6739
#     b:   -10.0000   -10.2520
#     d:     1.0000     0.9860

# %%
# %run -i bmsplot.py
# Out:
# <img src="data:image/png;base64,...">

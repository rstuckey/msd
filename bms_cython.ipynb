# %%
# %matplotlib notebook

# %%
MODEL = 'cython' # ['python', 'cython', 'boost']

# %%
DO_PYMC_MAP = True

# %%
DO_PYMC_MCMC = True

# %%
PLOT_MAP = True

# %%
PLOT_MCMC = True

# %%
NUM_SAMPLES = [ 100, 500 ]

# %%
# %run -i sim.py

# %%
# %run -i bms.py
# Out:
#  BUILDING PROBABILITY DISTRIBUTION MODEL
# <img src="data:image/png;base64,...">
#  BAYES ESTIMATE (MAXIMUM A-PRIORI):
# /home/rog/.virtualenvs/bms/local/lib/python2.7/site-packages/scipy/optimize/optimize.py:1881: RuntimeWarning: invalid value encountered in absolute
#   tmp2 = numpy.abs(tmp2)
# Time elapsed: 00h 00m 49s
#
#             TRUE      M_EST
#     k:   -50.0000   -48.7360
#     b:   -10.0000   -10.3709
#     d:     1.0000     0.9917
#  BAYES ESTIMATE (MARKOV CHAIN MONTE CARLO):
#  Switch PLOT_MCMC to False for this...
#
#  Chain 0:
#  [-----------------100%-----------------] 100 of 100 complete in 16.1 sec
#  Chain 1:
#  [-----------------100%-----------------] 501 of 500 complete in 77.8 sec
# Time elapsed: 00h 01m 33s
#             TRUE      B_EST
#     k:   -50.0000   -48.2529
#     b:   -10.0000   -10.5225
#     d:     1.0000     0.9951

# %%
# %run -i bmsplot.py
# Out:
# <img src="data:image/png;base64,...">

# %%
PLOT_MAP = False

# %%
PLOT_MCMC = False

# %%
NUM_SAMPLES = [ 100, 5000 ]

# %%
# %run -i bms.py
# Out:
#  BUILDING PROBABILITY DISTRIBUTION MODEL
#
#  BAYES ESTIMATE (MAXIMUM A-PRIORI):
#
# Time elapsed: 00h 00m 01s
#
#             TRUE      M_EST
#     k:   -50.0000   -48.6362
#     b:   -10.0000   -10.5225
#     d:     1.0000     0.9951
#  BAYES ESTIMATE (MARKOV CHAIN MONTE CARLO):
#
#  Chain 0:
#  [-----------------100%-----------------] 100 of 100 complete in 1.7 sec
#  Chain 1:
#  [-----------------100%-----------------] 5000 of 5000 complete in 78.6 sec
# Time elapsed: 00h 01m 20s
#             TRUE      B_EST
#     k:   -50.0000   -48.5581
#     b:   -10.0000   -10.2450
#     d:     1.0000     0.9864

# %%
# %run -i bmsplot.py
